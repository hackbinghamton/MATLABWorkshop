# %% [markdown]
# # Functions
#
# ## Overview
#
# ### What You'll Learn
# In this section, you'll learn
# 1. How to define a function
# 2. How to use parameters in functions
# 3. How to call a function
#
# ### Prerequisites
# Before starting this section, you should have an understanding of
# 1. Data Types and Variables
# 2. Printing
# 3. Control Flow
#
# ### Introduction
# In math if we have a function f(x)=x+4, then we compute f(2)=2+4=6. In other words, we have some input, which is 2, and after doing some operations using that input,  we will produce an output, which is 6. Similary, in MATLAB, a function carries out a certain task. Often times the function takes some input used to eventually produce an output or do something with the input. However, a function doesn't have to take input. There are certain functions that are included in MATLAB such as `disp()`. You also have the ability to make your own function. The proper syntax to create a function is `function [return parameters] = function_name(parameters)`, and then the write the code you want the function to do between the function statement and `end`.
#
# **MAKE A NOTE:** All functions must be defined **at the end of the file**, after the script code.

# %% [markdown]
# ---

# %% [markdown]
# ## Examples

# %% [markdown]
# The function f(x) = x + 4 would look like this in code if we wanted to print the result. Note that the name `adder` could be anything you wanted it to be.

# %% [markdown]
# ![1.PNG](data:image/png;base64,...)

# %% [markdown]
# Below is an example of a function that doesn't take any input. The function just prints "probably" when it is called.

# %% [markdown]
# ![2.PNG](data:image/png;base64,...)

# %% [markdown]
# To use our function we just need to write its name followed by parentheses. These print "6" and "probably"

# %% [markdown]
# ![3.PNG](data:image/png;base64,...)

# %% [markdown]
# ### Return Statements
# We can also write functions that have an output. To do this, we specify how many outputs and what we want to call them when declaring the function.

# %% [markdown]
# ```
# answer = is_twenty_six_too_many_cats();
# disp(answer);
#
# function output = is_twenty_seven_too_many_cats()
#     output = "yes";
# end
# ```

# %% [markdown]
# By putting **`output =`** before the function name, it specifies that the function will output something (in this case, the string `"yes"`). `output` could be called anything, that is just an example name.

# %% [markdown]
# ```
# result = adder(6);
# tripled = result * 3;
# disp(tripled);
#
# function y = adder(x)
#     y = x + 4;
# end
# ```

# %% [markdown]
# In this case, `result` is 10 and so `tripled` is 10*3 which is 30.
#
# Above you can also see how to call a function that takes input. You just put the value to be used as input in parentheses. This input is called a parameter.
#
# You can also pass in a parameter using a variable. The code below will print the same result as the code above.

# %% [markdown]
# ```
# num = 6;
# result = adder(num);
# tripled = result * 3;
# disp(tripled);
#
# function y = adder(x)
#     y = x + 4;
# end
# ```

# %% [markdown]
# Changing our function about cats from before, instead of automatically returning "yes", the number of cats you own can now be used as a parameter to determine if it's too many. Since the function returns "yes" for any number over 15, 26 is still too many cats.

# %% [markdown]
# ```
# disp(do_i_have_too_many_cats(3));
# disp(do_i_have_too_many_cats(65));
#
# my_cats = 437;
#
# disp(do_i_have_too_many_cats(my_cats));
#
# function answer = do_i_have_too_many_cats(num_cats)
#   if num_cats <= 15
#     answer = "no";
#   else
#     answer = "yes";
#   end
# end
# ```

# %% [markdown]
# Functions can also have more than one parameter.

# %% [markdown]
# ```
# my_cats_now = 2;
# my_future_cats = 900;
# disp(do_you_think_i_have_too_many_cats(my_cats_now, 5));
# disp(do_you_think_i_have_too_many_cats(my_future_cats, 5));
#
# function answer = do_you_think_i_have_too_many_cats(num_cats, your_limit)
#   if num_cats <= your_limit
#     answer = "no";
#   else
#     answer = "yes";
#   end
# end
# ```

# %% [markdown]
# ###Exercises
# Try out the following exercises!
#
# Make the function below print "Hack and Be You", and then call the function

# %% [markdown]
# ```
# function print_motto()
#     # Your code here
# end
# ```

# %% [markdown]
# Write a function `am_i_broke` that takes a parameter of the amount of money in your bank account. If the amount is less than 20, return "yes, I need a job." Otherwise, return "no, I'm buying everyone Market Place next week".

# %% [markdown]
# Write your own function that takes someone's name and the year they were born as parameters. Have the function print their name and age and return "legal" if they're currently above 21, otherwise return "illegal". Call the function and save the result in a variable named `legal_status`. Then, print the variable.

# %% [markdown]
# Complete the function `listEvaluator` to print 2 to the power of the length of the list `numbers` passed in, print the minimum value in `numbers`, and print the sum of the values in `numbers`:

# %% [markdown]
# ```
# myList= [1, 2, 16, 9, 12, 123, 22, 90];
# listEvaluator(myList);
#
# function listEvaluator(numbers)
#   #Implement Me!
# end
# ```
